# %% [markdown]
# # Worksheet 19
#
# Name:
# UID:
#
# ### Topics
#
# - Advanced Neural Networks
#
# ## Advanced Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# 2022-12-02 15:05:13.262722: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-02 15:05:19.280142: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7652
# Epoch 2/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7634
# Epoch 3/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7621
# Epoch 4/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7611
# Epoch 5/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7600
# Epoch 6/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7591
# Epoch 7/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7581
# Epoch 8/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7572
# Epoch 9/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7563
# Epoch 10/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7556
# Epoch 11/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7548
# Epoch 12/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7541
# Epoch 13/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7531
# Epoch 14/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7523
# Epoch 15/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7515
# Epoch 16/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7507
# Epoch 17/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7499
# Epoch 18/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7492
# Epoch 19/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7483
# Epoch 20/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7477
# Epoch 21/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7468
# Epoch 22/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7461
# Epoch 23/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7453
# Epoch 24/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7447
# Epoch 25/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7437
# Epoch 26/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7429
# Epoch 27/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7422
# Epoch 28/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7414
# Epoch 29/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7407
# Epoch 30/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7400
# Epoch 31/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7391
# Epoch 32/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7383
# Epoch 33/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7375
# Epoch 34/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7368
# Epoch 35/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7360
# Epoch 36/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7352
# Epoch 37/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7344
# Epoch 38/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7337
# Epoch 39/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7330
# Epoch 40/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7321
# Epoch 41/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7314
# Epoch 42/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7306
# Epoch 43/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7297
# Epoch 44/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7290
# Epoch 45/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7282
# Epoch 46/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7275
# Epoch 47/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7266
# Epoch 48/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7260
# Epoch 49/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7251
# Epoch 50/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7243
# Epoch 51/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7236
# Epoch 52/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7229
# Epoch 53/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7222
# Epoch 54/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7214
# Epoch 55/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7206
# Epoch 56/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7198
# Epoch 57/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7190
# Epoch 58/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7184
# Epoch 59/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7176
# Epoch 60/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7168
# Epoch 61/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7161
# Epoch 62/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7153
# Epoch 63/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7147
# Epoch 64/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7138
# Epoch 65/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7131
# Epoch 66/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7123
# Epoch 67/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7115
# Epoch 68/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7108
# Epoch 69/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7100
# Epoch 70/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7092
# Epoch 71/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7085
# Epoch 72/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7077
# Epoch 73/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7069
# Epoch 74/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7061
# Epoch 75/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7053
# Epoch 76/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7046
# Epoch 77/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7038
# Epoch 78/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7030
# Epoch 79/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7022
# Epoch 80/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7014
# Epoch 81/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7007
# Epoch 82/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6999
# Epoch 83/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6991
# Epoch 84/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6983
# Epoch 85/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6975
# Epoch 86/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6967
# Epoch 87/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6959
# Epoch 88/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6951
# Epoch 89/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6943
# Epoch 90/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6936
# Epoch 91/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6927
# Epoch 92/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6919
# Epoch 93/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6912
# Epoch 94/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6904
# Epoch 95/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6897
# Epoch 96/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6889
# Epoch 97/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6881
# Epoch 98/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6875
# Epoch 99/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6866
# Epoch 100/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6859
# Epoch 101/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6852
# Epoch 102/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6844
# Epoch 103/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6836
# Epoch 104/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6829
# Epoch 105/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6821
# Epoch 106/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6814
# Epoch 107/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6806
# Epoch 108/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6798
# Epoch 109/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6790
# Epoch 110/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6783
# Epoch 111/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6775
# Epoch 112/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6768
# Epoch 113/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6761
# Epoch 114/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6753
# Epoch 115/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6745
# Epoch 116/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6738
# Epoch 117/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6730
# Epoch 118/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6722
# Epoch 119/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6716
# Epoch 120/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6708
# Epoch 121/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6700
# Epoch 122/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6693
# Epoch 123/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6686
# Epoch 124/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6679
# Epoch 125/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6671
# Epoch 126/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6664
# Epoch 127/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6657
# Epoch 128/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6648
# Epoch 129/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6641
# Epoch 130/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6633
# Epoch 131/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6625
# Epoch 132/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6618
# Epoch 133/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6610
# Epoch 134/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6602
# Epoch 135/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6594
# Epoch 136/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6587
# Epoch 137/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6578
# Epoch 138/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6571
# Epoch 139/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6563
# Epoch 140/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6555
# Epoch 141/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6549
# Epoch 142/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6540
# Epoch 143/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6533
# Epoch 144/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6526
# Epoch 145/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6519
# Epoch 146/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6511
# Epoch 147/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6503
# Epoch 148/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6496
# Epoch 149/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6489
# Epoch 150/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6481
# Epoch 151/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6473
# Epoch 152/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6466
# Epoch 153/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6458
# Epoch 154/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6450
# Epoch 155/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6442
# Epoch 156/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6434
# Epoch 157/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6426
# Epoch 158/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6418
# Epoch 159/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6410
# Epoch 160/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6404
# Epoch 161/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6395
# Epoch 162/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6389
# Epoch 163/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6380
# Epoch 164/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6373
# Epoch 165/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6366
# Epoch 166/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6359
# Epoch 167/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6352
# Epoch 168/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6344
# Epoch 169/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6336
# Epoch 170/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6330
# Epoch 171/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6322
# Epoch 172/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6316
# Epoch 173/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6307
# Epoch 174/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6299
# Epoch 175/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6292
# Epoch 176/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6284
# Epoch 177/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6277
# Epoch 178/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6270
# Epoch 179/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6262
# Epoch 180/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6254
# Epoch 181/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6247
# Epoch 182/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6240
# Epoch 183/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6232
# Epoch 184/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6225
# Epoch 185/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6217
# Epoch 186/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6210
# Epoch 187/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6202
# Epoch 188/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6195
# Epoch 189/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6186
# Epoch 190/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6179
# Epoch 191/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6171
# Epoch 192/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6164
# Epoch 193/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6155
# Epoch 194/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6148
# Epoch 195/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6141
# Epoch 196/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6133
# Epoch 197/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6125
# Epoch 198/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6118
# Epoch 199/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6110
# Epoch 200/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6102
# 3602/3602 [==============================] - 3s 702us/step

# %% [markdown]
# ## Auto Encoder Example

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from tensorflow import keras, norm
from tensorflow.keras import layers

# Principal Component Extraction using Neural Net
#
# 
#       x[0]            x[0]' 
#          \            /
#           \          /
#            \        /
#       x[1]  \      /  x[1]'
#            \ \    / /   
#         .    \\  //    .
#         .  --- z ---   .
#         .    //  \\    .
#            / /    \ \
#      x[n-1] /      \ x[n-1]' 
#            /        \
#           /          \
#       x[n]             x[n]'
#
# where x' is the approximation of x based on the z components extracted

# MODIFY THIS LINE
RANK = 10

def custom_loss(y_true, y_pred):
    return norm(y_true - y_pred, ord='euclidean')

def frobenius(X, Y):
    return np.linalg.norm(X - Y, ord='fro')

boat = np.loadtxt('.boat.dat')
plt.figure()
_ = plt.imshow(boat,cmap = cm.Greys_r)
plt.show()

u,s,vt=np.linalg.svd(boat,full_matrices=False)
_ = plt.plot(s)
plt.title('Singular values of boat image')
plt.show()

# construct a rank-RANK version of the boat
scopy = s.copy()
scopy[RANK:]=0
boatApprox = u.dot(np.diag(scopy)).dot(vt)

model = keras.models.Sequential()
model.add(layers.Dense(RANK, use_bias=False, input_dim=len(boat)))
model.add(layers.Dense(len(boat), use_bias=False))
model.compile(loss=custom_loss)

history = model.fit(boat, boat, batch_size=50, epochs=500)

boatNNApprox = model.predict(boat)

print("Frobenius Distance between boat and rank-"+str(RANK)+" approximation: ", frobenius(boat, boatApprox))
print("Frobenius Distance between boat and NN output with 1 hidden layer of "+str(RANK)+" neurons: ", frobenius(boat, boatNNApprox))

plt.figure(figsize=(12,9))
plt.subplot(1,3,1)
plt.imshow(boatApprox,cmap = cm.Greys_r)
plt.title('Rank ' + str(RANK) + ' SVD Boat')
plt.subplot(1,3,2)
plt.imshow(boatNNApprox,cmap = cm.Greys_r)
plt.title('Rank ' + str(RANK) + ' NN Boat')
plt.subplot(1,3,3)
plt.imshow(boat,cmap = cm.Greys_r)
plt.title('Original Boat')

_ = plt.subplots_adjust(wspace=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/_h/n4z6x9sx4s18b6l_lb44jpzc0000gn/T/ipykernel_90356/2648644009.py in <module>
#      34     return np.linalg.norm(X - Y, ord='fro')
#      35
# ---> 36 boat = np.loadtxt('.boat.dat')
#      37 plt.figure()
#      38 _ = plt.imshow(boat,cmap = cm.Greys_r)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1336         delimiter = delimiter.decode('latin1')
#    1337
# -> 1338     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1339                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1340                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     973             fname = os.fspath(fname)
#     974         if isinstance(fname, str):
# --> 975             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     976             if encoding is None:
#     977                 encoding = getattr(fh, 'encoding', 'latin1')
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     528             if ext == 'bz2':
#     529                 mode.replace("+", "")
# --> 530             return _file_openers[ext](found, mode=mode,
#     531                                       encoding=encoding, newline=newline)
#     532         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '.boat.dat'

# %% [markdown]
# ## CNN Example

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from keras import utils
from keras.datasets import cifar10
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

X_train = X_train.astype('float32')/255.0
X_test = X_test.astype('float32')/255.0
mean = np.mean(X_train, axis = (0,1,2))
std = np.std(X_train, axis = (0,1,2))
X_train = (X_train-mean)/(std+1e-7)
X_test = (X_test-mean)/(std+1e-7)

fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(8, 8))
index = 0
for i in range(3):
    for j in range(3):
        axes[i,j].set_title(labels[y_train[index][0]])
        axes[i,j].imshow(X_train[index])
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        index += 1
plt.show()

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, utils.to_categorical(y_train), epochs=10, batch_size=1000, validation_data=(X_test, utils.to_categorical(y_test)))

plt.plot(history.history["accuracy"], label='train')
plt.plot(history.history["val_accuracy"], label='test')
plt.title('Classification Accuracy')
plt.legend()
plt.show()

plt.plot(history.history["loss"], label='train')
plt.plot(history.history["val_loss"], label='test')
plt.title('Cross Entropy Loss')
plt.legend()
plt.show()


predictions = model.predict(X_test)
cm = confusion_matrix(y_test, np.argmax(predictions,axis=1))
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=labels, yticklabels=labels, fmt='d', annot=True, cmap=plt.cm.Blues)
plt.title('RGB Network Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
